# %%
import pandas as pd
import requests
import json
import numpy as np

# %%
class NumpyEncoder(json.JSONEncoder):
    """ Special json encoder for numpy types """
    def default(self, obj):
        if isinstance(obj, (np.int_, np.intc, np.intp, np.int8,
            np.int16, np.int32, np.int64, np.uint8,
            np.uint16, np.uint32, np.uint64)):
            return int(obj)
        elif isinstance(obj, (np.float_, np.float16, np.float32, 
            np.float64)):
            return float(obj)
        elif isinstance(obj,(np.ndarray,)):
            return obj.tolist()
        return json.JSONEncoder.default(self, obj)

# %%
# IMD_XLSX = "https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/833970/File_1_-_IMD2019_Index_of_Multiple_Deprivation.xlsx"
# IMD_XLSX = "https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/833973/File_2_-_IoD2019_Domains_of_Deprivation.xlsx"
IMD_CSV = "https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/845345/File_7_-_All_IoD2019_Scores__Ranks__Deciles_and_Population_Denominators_3.csv"
# LSOA_BOUNDARIES = "https://opendata.arcgis.com/datasets/da831f80764346889837c72508f046fa_3.geojson"
# LSOA_BOUNDARIES = "https://opendata.arcgis.com/datasets/da831f80764346889837c72508f046fa_0.geojson"
LSOA_BOUNDARIES = "https://opendata.arcgis.com/datasets/da831f80764346889837c72508f046fa_2.geojson"

# %%
cols = {
    "LSOA code (2011)": "lsoa11cd",
    "LSOA name (2011)": "lsoa11nm",
    "Local Authority District code (2019)": "la19cd",
    "Local Authority District name (2019)": "la19nm",
    "Index of Multiple Deprivation (IMD) Score": "imd2019_score",
    "Index of Multiple Deprivation (IMD) Rank (where 1 is most deprived)": "imd2019_rank",
    "Index of Multiple Deprivation (IMD) Decile (where 1 is most deprived 10% of LSOAs)": "imd2019_decile",
    "Income Score (rate)": "imd2019_income_score",
    "Income Rank (where 1 is most deprived)": "imd2019_income_rank",
    "Income Decile (where 1 is most deprived 10% of LSOAs)": "imd2019_income_decile",
    "Employment Score (rate)": "imd2019_employment_score",
    "Employment Rank (where 1 is most deprived)": "imd2019_employment_rank",
    "Employment Decile (where 1 is most deprived 10% of LSOAs)": "imd2019_employment_decile",
    "Education, Skills and Training Score": "imd2019_education_score",
    "Education, Skills and Training Rank (where 1 is most deprived)": "imd2019_education_rank",
    "Education, Skills and Training Decile (where 1 is most deprived 10% of LSOAs)": "imd2019_education_decile",
    "Health Deprivation and Disability Score": "imd2019_health_score",
    "Health Deprivation and Disability Rank (where 1 is most deprived)": "imd2019_health_rank",
    "Health Deprivation and Disability Decile (where 1 is most deprived 10% of LSOAs)": "imd2019_health_decile",
    "Crime Score": "imd2019_crime_score",
    "Crime Rank (where 1 is most deprived)": "imd2019_crime_rank",
    "Crime Decile (where 1 is most deprived 10% of LSOAs)": "imd2019_crime_decile",
    "Barriers to Housing and Services Score": "imd2019_housing_score",
    "Barriers to Housing and Services Rank (where 1 is most deprived)": "imd2019_housing_rank",
    "Barriers to Housing and Services Decile (where 1 is most deprived 10% of LSOAs)": "imd2019_housing_decile",
    "Living Environment Score": "imd2019_environment_score",
    "Living Environment Rank (where 1 is most deprived)": "imd2019_environment_rank",
    "Living Environment Decile (where 1 is most deprived 10% of LSOAs)": "imd2019_environment_decile",
    'Income Deprivation Affecting Children Index (IDACI) Score (rate)': "imd2019_income_children_score",
    'Income Deprivation Affecting Children Index (IDACI) Rank (where 1 is most deprived)': "imd2019_income_children_rank",
    'Income Deprivation Affecting Children Index (IDACI) Decile (where 1 is most deprived 10% of LSOAs)': "imd2019_income_children_decile",
    'Income Deprivation Affecting Older People (IDAOPI) Score (rate)': "imd2019_income_older_score",
    'Income Deprivation Affecting Older People (IDAOPI) Rank (where 1 is most deprived)': "imd2019_income_older_rank",
    'Income Deprivation Affecting Older People (IDAOPI) Decile (where 1 is most deprived 10% of LSOAs)': "imd2019_income_older_decile",
    'Children and Young People Sub-domain Score': "imd2019_education_childrenyp_score",
    'Children and Young People Sub-domain Rank (where 1 is most deprived)': "imd2019_education_childrenyp_rank",
    'Children and Young People Sub-domain Decile (where 1 is most deprived 10% of LSOAs)': "imd2019_education_childrenyp_decile",
    'Adult Skills Sub-domain Score': "imd2019_education_adultskills_score",
    'Adult Skills Sub-domain Rank (where 1 is most deprived)': "imd2019_education_adultskills_rank",
    'Adult Skills Sub-domain Decile (where 1 is most deprived 10% of LSOAs)': "imd2019_education_adultskills_decile",
    'Geographical Barriers Sub-domain Score': "imd2019_housing_geobarriers_score",
    'Geographical Barriers Sub-domain Rank (where 1 is most deprived)': "imd2019_housing_geobarriers_rank",
    'Geographical Barriers Sub-domain Decile (where 1 is most deprived 10% of LSOAs)': "imd2019_housing_geobarriers_decile",
    'Wider Barriers Sub-domain Score': "imd2019_housing_widerbarriers_score",
    'Wider Barriers Sub-domain Rank (where 1 is most deprived)': "imd2019_housing_widerbarriers_rank",
    'Wider Barriers Sub-domain Decile (where 1 is most deprived 10% of LSOAs)': "imd2019_housing_widerbarriers_decile",
    'Indoors Sub-domain Score': "imd2019_environment_indoors_score",
    'Indoors Sub-domain Rank (where 1 is most deprived)': "imd2019_environment_indoors_rank",
    'Indoors Sub-domain Decile (where 1 is most deprived 10% of LSOAs)': "imd2019_environment_indoors_decile",
    'Outdoors Sub-domain Score': "imd2019_environment_outdoors_score",
    'Outdoors Sub-domain Rank (where 1 is most deprived)': "imd2019_environment_outdoors_rank",
    'Outdoors Sub-domain Decile (where 1 is most deprived 10% of LSOAs)': "imd2019_environment_outdoors_decile",
    'Total population: mid 2015 (excluding prisoners)': "population_2015",
    'Dependent Children aged 0-15: mid 2015 (excluding prisoners)': "population_0_15_2015",
    'Population aged 16-59: mid 2015 (excluding prisoners)': "population_16_59_2015",
    'Older population aged 60 and over: mid 2015 (excluding prisoners)': "population_60plus_2015",
    'Working age population 18-59/64: for use with Employment Deprivation Domain (excluding prisoners) ': "population_workingage_2015"
}

# %%
imd = pd.read_csv(IMD_CSV).rename(columns=cols).set_index('lsoa11cd')

# %%
for i in ['population_0_15_2015', 'population_16_59_2015', 'population_60plus_2015', 'population_workingage_2015']:
    imd.loc[:, i + "_pc"] = imd[i] / imd["population_2015"]

# %%
imd.sample(5)
# Out:
#                                 lsoa11nm     la19cd                    la19nm  \
# lsoa11cd
# E01018076                   Fenland 010B  E07000010                   Fenland
# E01011336                     Leeds 058C  E08000035                     Leeds
# E01005372                    Oldham 034A  E08000004                    Oldham
# E01012995  East Riding of Yorkshire 041B  E06000011  East Riding of Yorkshire
# E01024546                   Shepway 009D  E07000112      Folkestone and Hythe
#
#            imd2019_score  imd2019_rank  imd2019_decile  imd2019_income_score  \
# lsoa11cd
# E01018076         17.082         16915               6                 0.109
# E01011336         58.939          1019               1                 0.284
# E01005372         32.309          6964               3                 0.192
# E01012995         21.373         13252               5                 0.140
# E01024546         20.065         14292               5                 0.086
#
#            imd2019_income_rank  imd2019_income_decile  \
# lsoa11cd
# E01018076                15121                      5
# E01011336                 2742                      1
# E01005372                 7173                      3
# E01012995                11464                      4
# E01024546                18573                      6
#
#            imd2019_employment_score  ...  imd2019_environment_outdoors_decile  \
# lsoa11cd                             ...
# E01018076                     0.085  ...                                   10
# E01011336                     0.224  ...                                    2
# E01005372                     0.142  ...                                    4
# E01012995                     0.115  ...                                    7
# E01024546                     0.092  ...                                    9
#
#            population_2015  population_0_15_2015  population_16_59_2015  \
# lsoa11cd
# E01018076             2142                   377                   1184
# E01011336             1466                   248                    808
# E01005372             1178                   263                    664
# E01012995             2027                   462                   1185
# E01024546             1687                   276                    891
#
#            population_60plus_2015  population_workingage_2015  \
# lsoa11cd
# E01018076                     581                        1187
# E01011336                     410                         826
# E01005372                     251                         664
# E01012995                     380                        1186
# E01024546                     520                         911
#
#            population_0_15_2015_pc  population_16_59_2015_pc  \
# lsoa11cd
# E01018076                 0.176004                  0.552754
# E01011336                 0.169168                  0.551160
# E01005372                 0.223260                  0.563667
# E01012995                 0.227923                  0.584608
# E01024546                 0.163604                  0.528156
#
#            population_60plus_2015_pc  population_workingage_2015_pc
# lsoa11cd
# E01018076                   0.271242                       0.554155
# E01011336                   0.279673                       0.563438
# E01005372                   0.213073                       0.563667
# E01012995                   0.187469                       0.585101
# E01024546                   0.308239                       0.540012
#
# [5 rows x 60 columns]

# %%
imd[['lsoa11nm', 'la19nm', 'population_60plus_2015_pc']].sort_values('population_60plus_2015_pc', ascending=False).head(5)
# Out:
#                                     lsoa11nm                        la19nm  \
# lsoa11cd
# E01026707  King's Lynn and West Norfolk 017D  King's Lynn and West Norfolk
# E01020932                    Eastbourne 012B                    Eastbourne
# E01019355                South Lakeland 013D                South Lakeland
# E01019957                    East Devon 012B                    East Devon
# E01019913                    East Devon 020B                    East Devon
#
#            population_60plus_2015_pc
# lsoa11cd
# E01026707                   0.689794
# E01020932                   0.681466
# E01019355                   0.674803
# E01019957                   0.668129
# E01019913                   0.657706

# %%
imd[['lsoa11nm', 'la19nm', 'population_0_15_2015_pc']].sort_values('population_0_15_2015_pc', ascending=False).head(5)
# Out:
#                      lsoa11nm         la19nm  population_0_15_2015_pc
# lsoa11cd
# E01005614        Salford 016E        Salford                 0.529848
# E01005044           Bury 026E           Bury                 0.479339
# E01002052       Haringey 029C       Haringey                 0.450137
# E01033183  Richmondshire 004G  Richmondshire                 0.440051
# E01031988      Wiltshire 045B      Wiltshire                 0.432031

# %%
# r = requests.get(LSOA_BOUNDARIES)
# lsoa = r.json()
with open("lsoa.geojson") as a:
    lsoa = json.load(a)

# %%
add_cols = imd.dtypes[imd.dtypes.apply(pd.api.types.is_numeric_dtype)].index.tolist()
add_cols = [c for c in imd.columns if c.endswith('_rank') or c.endswith('nm')] + ['imd2019_decile']
new_lsoa = {
    "type": 'FeatureCollection',
    "features": []
}
for i in lsoa['features']:
    if i["properties"]['lsoa11cd'] in imd.index:
        i['properties'].update(
            imd.loc[i["properties"]['lsoa11cd'], add_cols].to_dict()
        )
        new_lsoa["features"].append(i)
lsoa = new_lsoa

# %%
for i in lsoa['features'][0:10]:
    print(json.dumps(i['properties'], indent=4, cls=NumpyEncoder))
# Out:
# {
#     "objectid": 1,
#     "lsoa11cd": "E01000001",
#     "lsoa11nm": "City of London 001A",
#     "lsoa11nmw": "City of London 001A",
#     "st_areashape": 133320.7688715,
#     "st_lengthshape": 2291.846072147722,
#     "la19nm": "City of London",
#     "imd2019_rank": 29199,
#     "imd2019_income_rank": 32831,
#     "imd2019_employment_rank": 32742,
#     "imd2019_education_rank": 32842,
#     "imd2019_health_rank": 32113,
#     "imd2019_crime_rank": 32662,
#     "imd2019_housing_rank": 7319,
#     "imd2019_environment_rank": 7789,
#     "imd2019_income_children_rank": 32806,
#     "imd2019_income_older_rank": 32820,
#     "imd2019_education_childrenyp_rank": 32777,
#     "imd2019_education_adultskills_rank": 32843,
#     "imd2019_housing_geobarriers_rank": 22985,
#     "imd2019_housing_widerbarriers_rank": 3216,
#     "imd2019_environment_indoors_rank": 16364,
#     "imd2019_environment_outdoors_rank": 1615,
#     "imd2019_decile": 9
# }
# {
#     "objectid": 2,
#     "lsoa11cd": "E01000002",
#     "lsoa11nm": "City of London 001B",
#     "lsoa11nmw": "City of London 001B",
#     "st_areashape": 226191.27299,
#     "st_lengthshape": 2433.9601119492254,
#     "la19nm": "City of London",
#     "imd2019_rank": 30379,
#     "imd2019_income_rank": 29901,
#     "imd2019_employment_rank": 31190,
#     "imd2019_education_rank": 32832,
#     "imd2019_health_rank": 29705,
#     "imd2019_crime_rank": 32789,
#     "imd2019_housing_rank": 11707,
#     "imd2019_environment_rank": 13070,
#     "imd2019_income_children_rank": 29682,
#     "imd2019_income_older_rank": 31938,
#     "imd2019_education_childrenyp_rank": 32666,
#     "imd2019_education_adultskills_rank": 32841,
#     "imd2019_housing_geobarriers_rank": 30223,
#     "imd2019_housing_widerbarriers_rank": 3894,
#     "imd2019_environment_indoors_rank": 22676,
#     "imd2019_environment_outdoors_rank": 2969,
#     "imd2019_decile": 10
# }
# {
#     "objectid": 3,
#     "lsoa11cd": "E01000003",
#     "lsoa11nm": "City of London 001C",
#     "lsoa11nmw": "City of London 001C",
#     "st_areashape": 57302.966538,
#     "st_lengthshape": 1142.359798690797,
#     "la19nm": "City of London",
#     "imd2019_rank": 14915,
#     "imd2019_income_rank": 18510,
#     "imd2019_employment_rank": 15103,
#     "imd2019_education_rank": 26386,
#     "imd2019_health_rank": 17600,
#     "imd2019_crime_rank": 29363,
#     "imd2019_housing_rank": 2157,
#     "imd2019_environment_rank": 4092,
#     "imd2019_income_children_rank": 27063,
#     "imd2019_income_older_rank": 16377,
#     "imd2019_education_childrenyp_rank": 20837,
#     "imd2019_education_adultskills_rank": 30999,
#     "imd2019_housing_geobarriers_rank": 26719,
#     "imd2019_housing_widerbarriers_rank": 818,
#     "imd2019_environment_indoors_rank": 17318,
#     "imd2019_environment_outdoors_rank": 162,
#     "imd2019_decile": 5
# }
# {
#     "objectid": 4,
#     "lsoa11cd": "E01000005",
#     "lsoa11nm": "City of London 001E",
#     "lsoa11nmw": "City of London 001E",
#     "st_areashape": 190738.760504,
#     "st_lengthshape": 2167.868343078632,
#     "la19nm": "City of London",
#     "imd2019_rank": 8678,
#     "imd2019_income_rank": 6029,
#     "imd2019_employment_rank": 7833,
#     "imd2019_education_rank": 12370,
#     "imd2019_health_rank": 17907,
#     "imd2019_crime_rank": 31059,
#     "imd2019_housing_rank": 2217,
#     "imd2019_environment_rank": 9397,
#     "imd2019_income_children_rank": 9458,
#     "imd2019_income_older_rank": 3885,
#     "imd2019_education_childrenyp_rank": 10914,
#     "imd2019_education_adultskills_rank": 13658,
#     "imd2019_housing_geobarriers_rank": 30865,
#     "imd2019_housing_widerbarriers_rank": 672,
#     "imd2019_environment_indoors_rank": 25218,
#     "imd2019_environment_outdoors_rank": 849,
#     "imd2019_decile": 3
# }
# {
#     "objectid": 5,
#     "lsoa11cd": "E01000006",
#     "lsoa11nm": "Barking and Dagenham 016A",
#     "lsoa11nmw": "Barking and Dagenham 016A",
#     "st_areashape": 144195.846857,
#     "st_lengthshape": 1935.5103542093034,
#     "la19nm": "Barking and Dagenham",
#     "imd2019_rank": 14486,
#     "imd2019_income_rank": 14023,
#     "imd2019_employment_rank": 21692,
#     "imd2019_education_rank": 17511,
#     "imd2019_health_rank": 21581,
#     "imd2019_crime_rank": 18848,
#     "imd2019_housing_rank": 1033,
#     "imd2019_environment_rank": 10629,
#     "imd2019_income_children_rank": 13592,
#     "imd2019_income_older_rank": 12934,
#     "imd2019_education_childrenyp_rank": 21932,
#     "imd2019_education_adultskills_rank": 13244,
#     "imd2019_housing_geobarriers_rank": 22527,
#     "imd2019_housing_widerbarriers_rank": 520,
#     "imd2019_environment_indoors_rank": 14745,
#     "imd2019_environment_outdoors_rank": 4368,
#     "imd2019_decile": 5
# }
# {
#     "objectid": 6,
#     "lsoa11cd": "E01000007",
#     "lsoa11nm": "Barking and Dagenham 015A",
#     "lsoa11nmw": "Barking and Dagenham 015A",
#     "st_areashape": 198134.809244,
#     "st_lengthshape": 2824.0369143671633,
#     "la19nm": "Barking and Dagenham",
#     "imd2019_rank": 7256,
#     "imd2019_income_rank": 6261,
#     "imd2019_employment_rank": 11487,
#     "imd2019_education_rank": 20536,
#     "imd2019_health_rank": 16414,
#     "imd2019_crime_rank": 4925,
#     "imd2019_housing_rank": 274,
#     "imd2019_environment_rank": 11162,
#     "imd2019_income_children_rank": 6750,
#     "imd2019_income_older_rank": 2514,
#     "imd2019_education_childrenyp_rank": 18304,
#     "imd2019_education_adultskills_rank": 21531,
#     "imd2019_housing_geobarriers_rank": 29432,
#     "imd2019_housing_widerbarriers_rank": 33,
#     "imd2019_environment_indoors_rank": 20820,
#     "imd2019_environment_outdoors_rank": 2319,
#     "imd2019_decile": 3
# }
# {
#     "objectid": 7,
#     "lsoa11cd": "E01000008",
#     "lsoa11nm": "Barking and Dagenham 015B",
#     "lsoa11nmw": "Barking and Dagenham 015B",
#     "st_areashape": 193425.098879,
#     "st_lengthshape": 3908.3665760232643,
#     "la19nm": "Barking and Dagenham",
#     "imd2019_rank": 5010,
#     "imd2019_income_rank": 3382,
#     "imd2019_employment_rank": 6431,
#     "imd2019_education_rank": 10569,
#     "imd2019_health_rank": 12334,
#     "imd2019_crime_rank": 11113,
#     "imd2019_housing_rank": 981,
#     "imd2019_environment_rank": 8672,
#     "imd2019_income_children_rank": 4452,
#     "imd2019_income_older_rank": 893,
#     "imd2019_education_childrenyp_rank": 14007,
#     "imd2019_education_adultskills_rank": 7918,
#     "imd2019_housing_geobarriers_rank": 24033,
#     "imd2019_housing_widerbarriers_rank": 443,
#     "imd2019_environment_indoors_rank": 25009,
#     "imd2019_environment_outdoors_rank": 674,
#     "imd2019_decile": 2
# }
# {
#     "objectid": 8,
#     "lsoa11cd": "E01000009",
#     "lsoa11nm": "Barking and Dagenham 016B",
#     "lsoa11nmw": "Barking and Dagenham 016B",
#     "st_areashape": 128591.526205,
#     "st_lengthshape": 2065.959114273154,
#     "la19nm": "Barking and Dagenham",
#     "imd2019_rank": 6736,
#     "imd2019_income_rank": 7506,
#     "imd2019_employment_rank": 11132,
#     "imd2019_education_rank": 16819,
#     "imd2019_health_rank": 9661,
#     "imd2019_crime_rank": 4431,
#     "imd2019_housing_rank": 554,
#     "imd2019_environment_rank": 9611,
#     "imd2019_income_children_rank": 10487,
#     "imd2019_income_older_rank": 2238,
#     "imd2019_education_childrenyp_rank": 14445,
#     "imd2019_education_adultskills_rank": 18554,
#     "imd2019_housing_geobarriers_rank": 31919,
#     "imd2019_housing_widerbarriers_rank": 92,
#     "imd2019_environment_indoors_rank": 18146,
#     "imd2019_environment_outdoors_rank": 2131,
#     "imd2019_decile": 3
# }
# {
#     "objectid": 9,
#     "lsoa11cd": "E01000010",
#     "lsoa11nm": "Barking and Dagenham 015C",
#     "lsoa11nmw": "Barking and Dagenham 015C",
#     "st_areashape": 348848.342174,
#     "st_lengthshape": 3097.6228266203248,
#     "la19nm": "Barking and Dagenham",
#     "imd2019_rank": 6900,
#     "imd2019_income_rank": 8902,
#     "imd2019_employment_rank": 17988,
#     "imd2019_education_rank": 20182,
#     "imd2019_health_rank": 16050,
#     "imd2019_crime_rank": 2164,
#     "imd2019_housing_rank": 259,
#     "imd2019_environment_rank": 2269,
#     "imd2019_income_children_rank": 8757,
#     "imd2019_income_older_rank": 531,
#     "imd2019_education_childrenyp_rank": 15696,
#     "imd2019_education_adultskills_rank": 24261,
#     "imd2019_housing_geobarriers_rank": 30844,
#     "imd2019_housing_widerbarriers_rank": 6,
#     "imd2019_environment_indoors_rank": 4411,
#     "imd2019_environment_outdoors_rank": 2600,
#     "imd2019_decile": 3
# }
# {
#     "objectid": 10,
#     "lsoa11cd": "E01000011",
#     "lsoa11nm": "Barking and Dagenham 016C",
#     "lsoa11nmw": "Barking and Dagenham 016C",
#     "st_areashape": 90297.6798095,
#     "st_lengthshape": 1496.0303645039949,
#     "la19nm": "Barking and Dagenham",
#     "imd2019_rank": 7698,
#     "imd2019_income_rank": 9033,
#     "imd2019_employment_rank": 16108,
#     "imd2019_education_rank": 12224,
#     "imd2019_health_rank": 18178,
#     "imd2019_crime_rank": 8727,
#     "imd2019_housing_rank": 110,
#     "imd2019_environment_rank": 4309,
#     "imd2019_income_children_rank": 10815,
#     "imd2019_income_older_rank": 2747,
#     "imd2019_education_childrenyp_rank": 11826,
#     "imd2019_education_adultskills_rank": 12319,
#     "imd2019_housing_geobarriers_rank": 21499,
#     "imd2019_housing_widerbarriers_rank": 76,
#     "imd2019_environment_indoors_rank": 7302,
#     "imd2019_environment_outdoors_rank": 2975,
#     "imd2019_decile": 3
# }

# %%
with open('imd2019.geojson', 'w') as a:
    json.dump(lsoa, a, cls=NumpyEncoder)

# %%
len(lsoa["features"])
# Out:
# 32844
